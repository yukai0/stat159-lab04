# %%
# this is dataset
#c 
import pandas as pd
import numpy as np

np.random.seed(42)
data = {
    'Transaction_ID': range(1001, 1101),
    'Store_ID': np.random.choice(['Store_A', 'Store_B', 'Store_C', None], 100, p=[0.4, 0.3, 0.2, 0.1]),
    'Revenue': np.random.choice([50, 120, 250, 500, np.nan], 100, p=[0.3, 0.4, 0.15, 0.10, 0.05]),
    'Units_Sold': np.random.randint(1, 12, size=100)
}
df = pd.DataFrame(data)
df
# Out:
#     Transaction_ID Store_ID  Revenue  Units_Sold
# 0             1001  Store_A     50.0           8
# 1             1002      NaN    120.0           4
# 2             1003  Store_C    120.0          11
# 3             1004  Store_B    120.0           1
# 4             1005  Store_A    500.0           8
# ..             ...      ...      ...         ...
# 95            1096  Store_B    120.0           2
# 96            1097  Store_B    250.0           9
# 97            1098  Store_B    500.0           8
# 98            1099  Store_A    500.0          10
# 99            1100  Store_A    250.0           7
#
# [100 rows x 4 columns]
